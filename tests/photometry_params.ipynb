# %%
import batman
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
params = batman.TransitParams()
params.t0 = 0.                       #time of inferior conjunction
params.per = 1.                      #orbital period
params.rp = 0.1                      #planet radius (in units of stellar radii)
params.a = 15.                       #semi-major axis (in units of stellar radii)
params.inc = 87.                     #orbital inclination (in degrees)
params.ecc = 0.                      #eccentricity
params.w = 90.                       #longitude of periastron (in degrees)
params.u = [0.1, 0.3]                #limb darkening coefficients [u1, u2]
params.limb_dark = "quadratic"       #limb darkening model

# %%
t = np.linspace(-0.025, 0.025, 1000)

# %%
m = batman.TransitModel(params, t)    #initializes model
flux = m.light_curve(params)          #calculates light curve

# %%
fig = plt.figure(figsize=(14,8))
plt.plot(t, flux)
plt.xlabel("Time from central transit")
plt.ylabel("Relative flux")
plt.show()

# %%
radii = np.linspace(0.09, 0.11, 5)
fig = plt.figure(figsize=(14,8))
plt.title('Different Radii', fontsize=24)
for r in radii:
    params.rp = r                           #updates planet radius
    new_flux = m.light_curve(params)        #recalculates light curve
    plt.plot(t, new_flux, label='Val %s' % str(r))
    plt.legend()
    plt.xlabel("Time from central transit", fontsize=21)
    plt.ylabel("Relative flux", fontsize=21)

# %%
params.t0 = 0.                       #time of inferior conjunction
params.per = 1.                      #orbital period
params.rp = 0.1                      #planet radius (in units of stellar radii)
params.a = 15.                       #semi-major axis (in units of stellar radii)
params.inc = 87.                     #orbital inclination (in degrees)
params.ecc = 0.                      #eccentricity
params.w = 90.                       #longitude of periastron (in degrees)
params.u = [0.1, 0.3]                #limb darkening coefficients [u1, u2]
params.limb_dark = "quadratic"       #limb darkening model
t0s = np.linspace(-0.01, 0.01, 5)
fig = plt.figure(figsize=(14,8))
plt.title('Different T0s', fontsize=24)
for t00 in t0s:
    params.t0 = t00                           #updates planet radius
    new_flux = m.light_curve(params)        #recalculates light curve
    plt.plot(t, new_flux, label='Val %s' % str(t00))
    plt.legend()
    plt.xlabel("Time from central transit", fontsize=21)
    plt.ylabel("Relative flux", fontsize=21)

# %%
params.t0 = 0.                       #time of inferior conjunction
params.per = 1.                      #orbital period
params.rp = 0.1                      #planet radius (in units of stellar radii)
params.a = 15.                       #semi-major axis (in units of stellar radii)
params.inc = 87.                     #orbital inclination (in degrees)
params.ecc = 0.                      #eccentricity
params.w = 90.                       #longitude of periastron (in degrees)
params.u = [0.1, 0.3]                #limb darkening coefficients [u1, u2]
params.limb_dark = "quadratic"       #limb darkening model
P = np.linspace(0.7, 1.4, 5)
fig = plt.figure(figsize=(14,8))
plt.title('Different Periods', fontsize=24)
for p in P:
    params.per = p                           #updates planet radius
    new_flux = m.light_curve(params)        #recalculates light curve
    plt.plot(t, new_flux, label='Val %s' % str(p))
    plt.legend()
    plt.xlabel("Time from central transit", fontsize=21)
    plt.ylabel("Relative flux", fontsize=21)

# %%
params.t0 = 0.                       #time of inferior conjunction
params.per = 1.                      #orbital period
params.rp = 0.1                      #planet radius (in units of stellar radii)
params.a = 15.                       #semi-major axis (in units of stellar radii)
params.inc = 87.                     #orbital inclination (in degrees)
params.ecc = 0.                      #eccentricity
params.w = 90.                       #longitude of periastron (in degrees)
params.u = [0.1, 0.3]                #limb darkening coefficients [u1, u2]
params.limb_dark = "quadratic"       #limb darkening model

A = np.linspace(10, 20, 5)
fig = plt.figure(figsize=(14,8))
plt.title('Different SMA', fontsize=24)
for a in A:
    params.a = a                           #updates planet radius
    new_flux = m.light_curve(params)        #recalculates light curve
    plt.plot(t, new_flux, label='Val %s' % str(a))
    plt.legend()
    plt.xlabel("Time from central transit", fontsize=21)
    plt.ylabel("Relative flux", fontsize=21)

# %%
params.t0 = 0.                       #time of inferior conjunction
params.per = 1.                      #orbital period
params.rp = 0.1                      #planet radius (in units of stellar radii)
params.a = 15.                       #semi-major axis (in units of stellar radii)
params.inc = 87.                     #orbital inclination (in degrees)
params.ecc = 0.                      #eccentricity
params.w = 90.                       #longitude of periastron (in degrees)
params.u = [0.1, 0.3]                #limb darkening coefficients [u1, u2]
params.limb_dark = "quadratic"       #limb darkening model

I = np.linspace(85, 89, 5)
fig = plt.figure(figsize=(14,8))
plt.title('Different Inclinations', fontsize=24)
for i in I:
    params.inc = i                           #updates planet radius
    new_flux = m.light_curve(params)        #recalculates light curve
    plt.plot(t, new_flux, label='Val %s' % str(i))
    plt.legend()
    plt.xlabel("Time from central transit", fontsize=21)
    plt.ylabel("Relative flux", fontsize=21)

# %%
params.t0 = 0.                       #time of inferior conjunction
params.per = 1.                      #orbital period
params.rp = 0.1                      #planet radius (in units of stellar radii)
params.a = 15.                       #semi-major axis (in units of stellar radii)
params.inc = 87.                     #orbital inclination (in degrees)
params.ecc = 0.                      #eccentricity
params.w = 90.                       #longitude of periastron (in degrees)
params.u = [0.1, 0.3]                #limb darkening coefficients [u1, u2]
params.limb_dark = "quadratic"       #limb darkening model

E = np.linspace(0., 1, 5)
fig = plt.figure(figsize=(14,8))
plt.title('Different Eccentricities', fontsize=24)
for ecc in E:
    params.ecc = ecc                           #updates planet radius
    new_flux = m.light_curve(params)        #recalculates light curve
    plt.plot(t, new_flux, label='Val %s' % str(ecc))
    plt.legend()
    plt.xlabel("Time from central transit", fontsize=21)
    plt.ylabel("Relative flux", fontsize=21)

# %%
params.t0 = 0.                       #time of inferior conjunction
params.per = 1.                      #orbital period
params.rp = 0.2                      #planet radius (in units of stellar radii)
params.a = 15.                       #semi-major axis (in units of stellar radii)
params.inc = 90.                     #orbital inclination (in degrees)
params.ecc = 0.0                      #eccentricity
params.w = 0.                       #longitude of periastron (in degrees)
params.u = [0.1, 0.3]                #limb darkening coefficients [u1, u2]
params.limb_dark = "quadratic"       #limb darkening model

W = np.linspace(70, 110, 30)
fig = plt.figure(figsize=(14,8))
plt.title('Different Longitudes', fontsize=24)
for wi in W:
    params.w = wi                           #updates planet radius
    new_flux = m.light_curve(params)        #recalculates light curve
    plt.plot(t, new_flux)
    plt.xlabel("Time from central transit", fontsize=21)
    plt.ylabel("Relative flux", fontsize=21)
